# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('img2.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
edges = cv2.Canny(gray, 100, 200)
edges_rgb = cv2.cvtColor(edges, cv2.COLOR_GRAY2RGB)
ret, thresh = cv2.threshold(edges, 127, 255, cv2.THRESH_BINARY)
thresh = cv2.bitwise_not(thresh)

blur = cv2.GaussianBlur(img, (127, 127), 0)

result = cv2.addWeighted(blur, 0.8, edges_rgb, 0.2, 0)
result[thresh==0] = [0, 0, 0]

plt.figure(figsize=(12, 8))
plt.title("Cartoonized image")
plt.imshow(result)
plt.axis("off")
plt.show()

plt.figure(figsize=(20, 10))

plt.subplot(1, 3, 1)
plt.title("Original image")
plt.imshow(img)
plt.axis("off")

plt.subplot(1, 3, 2)
plt.title("Edges")
plt.imshow(thresh, cmap='gray')
plt.axis("off")

plt.subplot(1, 3, 3)
plt.title("Cartoonized image")
plt.imshow(result)
plt.axis("off")

plt.show()

# %%
img = cv2.imread('img1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
edges = cv2.Canny(gray, 100, 200)
edges_rgb = cv2.cvtColor(edges, cv2.COLOR_GRAY2RGB)
ret, thresh = cv2.threshold(edges, 127, 255, cv2.THRESH_BINARY)
thresh = cv2.bitwise_not(thresh)

blur = cv2.GaussianBlur(img, (65, 65), 0)

result = cv2.addWeighted(blur, 0.8, edges_rgb, 0.2, 0)
result[thresh==0] = [0, 0, 0]

plt.figure(figsize=(12, 8))
plt.title("Cartoonized image")
plt.imshow(result)
plt.axis("off")
plt.show()

plt.figure(figsize=(20, 10))

plt.subplot(1, 3, 1)
plt.title("Original image")
plt.imshow(img)
plt.axis("off")

plt.subplot(1, 3, 2)
plt.title("Edges")
plt.imshow(thresh, cmap='gray')
plt.axis("off")

plt.subplot(1, 3, 3)
plt.title("Cartoonized image")
plt.imshow(result)
plt.axis("off")

plt.show()
